# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from photonscore.python.vault import Vault

# %%
data = Vault("d:/rawData/01_2Ions_12uW2.photons")

# %%
data
# Out:
# [d:/rawData/01_2Ions_12uW2.photons]
# Datasets:
#   /master/aux/aat      uint64   [265072]
#   /master/aux/aux      uint16   [265072]
#   /master/photons/a    uint16   [5559306]
#   /master/photons/aat  uint64   [5559306]
#   /master/photons/aux  uint16   [5559306]
#   /master/photons/tac  uint16   [5559306]
#   /master/photons/x    uint16   [5559306]
#   /master/photons/y    uint16   [5559306]
#   /master/status/aat   uint64   [901210]
#   /master/status/aux   uint16   [901210]
#   /master/status/daq_counts uint64   [901210]
#   /master/status/mcp_counts uint64   [901210]
#   /master/status/temperature float32  [901210]
#   /slave/aux/aat       uint64   [265072]
#   /slave/aux/aux       uint16   [265072]
#   /slave/photons/a     uint16   [7338647]
#   /slave/photons/aat   uint64   [7338647]
#   /slave/photons/aux   uint16   [7338647]
#   /slave/photons/tac   uint16   [7338647]
#   /slave/photons/x     uint16   [7338647]
#   /slave/photons/y     uint16   [7338647]
# ...

# %%
countrateMaster = data.data.master.status.daq_counts[:]
countrateSlave = data.data.slave.status.daq_counts[:]

# %%
plt.figure()
plt.plot(np.diff(countrateMaster[::1000]))
plt.plot(np.diff(countrateSlave[::1000]))
plt.show()

# %%
data = Vault("d:/rawData/07_2Ions_12uW79.photons")

# %%
data
# Out:
# [d:/rawData/07_2Ions_12uW79.photons]
# Datasets:
#   /master/aux/aat      uint64   [212936]
#   /master/aux/aux      uint16   [212936]
#   /master/photons/a    uint16   [4822041]
#   /master/photons/aat  uint64   [4822041]
#   /master/photons/aux  uint16   [4822041]
#   /master/photons/tac  uint16   [4822041]
#   /master/photons/x    uint16   [4822041]
#   /master/photons/y    uint16   [4822041]
#   /master/status/aat   uint64   [901205]
#   /master/status/aux   uint16   [901205]
#   /master/status/daq_counts uint64   [901205]
#   /master/status/mcp_counts uint64   [901205]
#   /master/status/temperature float32  [901205]
#   /slave/aux/aat       uint64   [212936]
#   /slave/aux/aux       uint16   [212936]
#   /slave/photons/a     uint16   [6355593]
#   /slave/photons/aat   uint64   [6355593]
#   /slave/photons/aux   uint16   [6355593]
#   /slave/photons/tac   uint16   [6355593]
#   /slave/photons/x     uint16   [6355593]
#   /slave/photons/y     uint16   [6355593]
# ...

# %%
countrateMaster = data.data.master.status.daq_counts[:]
countrateSlave = data.data.slave.status.daq_counts[:]

# %%
plt.figure()
plt.plot(np.diff(countrateMaster[::1000]))
plt.plot(np.diff(countrateSlave[::1000]))
plt.show()

# %%
data = Vault("d:/rawData/07_2Ions_12uW605.photons")

# %%
data
# Out:
# [d:/rawData/07_2Ions_12uW623.photons]
# Datasets:
#   /master/aux/aat      uint64   [247540]
#   /master/aux/aux      uint16   [247540]
#   /master/photons/a    uint16   [5265717]
#   /master/photons/aat  uint64   [5265717]
#   /master/photons/aux  uint16   [5265717]
#   /master/photons/tac  uint16   [5265717]
#   /master/photons/x    uint16   [5265717]
#   /master/photons/y    uint16   [5265717]
#   /master/status/aat   uint64   [901198]
#   /master/status/aux   uint16   [901198]
#   /master/status/daq_counts uint64   [901198]
#   /master/status/mcp_counts uint64   [901198]
#   /master/status/temperature float32  [901198]
#   /slave/aux/aat       uint64   [247540]
#   /slave/aux/aux       uint16   [247540]
#   /slave/photons/a     uint16   [6969750]
#   /slave/photons/aat   uint64   [6969750]
#   /slave/photons/aux   uint16   [6969750]
#   /slave/photons/tac   uint16   [6969750]
#   /slave/photons/x     uint16   [6969750]
#   /slave/photons/y     uint16   [6969750]
# ...

# %%
countrateMaster = data.data.master.status.daq_counts[:]
countrateSlave = data.data.slave.status.daq_counts[:]

# %%
plt.figure()
plt.plot(np.diff(countrateMaster[::1000]))
plt.plot(np.diff(countrateSlave[::1000]))
plt.show()

# %%
data = Vault("d:/rawData/09_2Ions_12uW16.photons")

# %%
data
# Out:
# [d:/rawData/09_2Ions_12uW16.photons]
# Datasets:
#   /master/aux/aat      uint64   [230168]
#   /master/aux/aux      uint16   [230168]
#   /master/photons/a    uint16   [4452671]
#   /master/photons/aat  uint64   [4452671]
#   /master/photons/aux  uint16   [4452671]
#   /master/photons/tac  uint16   [4452671]
#   /master/photons/x    uint16   [4452671]
#   /master/photons/y    uint16   [4452671]
#   /master/status/aat   uint64   [901211]
#   /master/status/aux   uint16   [901211]
#   /master/status/daq_counts uint64   [901211]
#   /master/status/mcp_counts uint64   [901211]
#   /master/status/temperature float32  [901211]
#   /slave/aux/aat       uint64   [230168]
#   /slave/aux/aux       uint16   [230168]
#   /slave/photons/a     uint16   [5917581]
#   /slave/photons/aat   uint64   [5917581]
#   /slave/photons/aux   uint16   [5917581]
#   /slave/photons/tac   uint16   [5917581]
#   /slave/photons/x     uint16   [5917581]
#   /slave/photons/y     uint16   [5917581]
# ...

# %%
countrateMaster = data.data.master.status.daq_counts[:]
countrateSlave = data.data.slave.status.daq_counts[:]

# %%
plt.figure()
plt.plot(np.diff(countrateMaster[::1000]))
plt.plot(np.diff(countrateSlave[::1000]))
plt.show()

# %%
data = Vault("d:/rawData/08_2Ions_12uW92.photons")

# %%
data
# Out:
# [d:/rawData/08_2Ions_12uW92.photons]
# Datasets:
#   /master/aux/aat      uint64   [222560]
#   /master/aux/aux      uint16   [222560]
#   /master/photons/a    uint16   [5605534]
#   /master/photons/aat  uint64   [5605534]
#   /master/photons/aux  uint16   [5605534]
#   /master/photons/tac  uint16   [5605534]
#   /master/photons/x    uint16   [5605534]
#   /master/photons/y    uint16   [5605534]
#   /master/status/aat   uint64   [901290]
#   /master/status/aux   uint16   [901290]
#   /master/status/daq_counts uint64   [901290]
#   /master/status/mcp_counts uint64   [901290]
#   /master/status/temperature float32  [901290]
#   /slave/aux/aat       uint64   [222564]
#   /slave/aux/aux       uint16   [222564]
#   /slave/photons/a     uint16   [7423542]
#   /slave/photons/aat   uint64   [7423542]
#   /slave/photons/aux   uint16   [7423542]
#   /slave/photons/tac   uint16   [7423542]
#   /slave/photons/x     uint16   [7423542]
#   /slave/photons/y     uint16   [7423542]
# ...

# %%
countrateMaster = data.data.master.status.daq_counts[:]
countrateSlave = data.data.slave.status.daq_counts[:]

# %%
plt.figure()
plt.plot(np.diff(countrateMaster[::1000]))
plt.plot(np.diff(countrateSlave[::1000]))
plt.show()

# %%
data = Vault("d:/rawData/07_2Ions_12uW607.photons")

# %%
data
# Out:
# [d:/rawData/07_2Ions_12uW607.photons]
# Datasets:
#   /master/aux/aat      uint64   [242212]
#   /master/aux/aux      uint16   [242212]
#   /master/photons/a    uint16   [5277646]
#   /master/photons/aat  uint64   [5277646]
#   /master/photons/aux  uint16   [5277646]
#   /master/photons/tac  uint16   [5277646]
#   /master/photons/x    uint16   [5277646]
#   /master/photons/y    uint16   [5277646]
#   /master/status/aat   uint64   [901225]
#   /master/status/aux   uint16   [901225]
#   /master/status/daq_counts uint64   [901225]
#   /master/status/mcp_counts uint64   [901225]
#   /master/status/temperature float32  [901225]
#   /slave/aux/aat       uint64   [242212]
#   /slave/aux/aux       uint16   [242212]
#   /slave/photons/a     uint16   [6967274]
#   /slave/photons/aat   uint64   [6967274]
#   /slave/photons/aux   uint16   [6967274]
#   /slave/photons/tac   uint16   [6967274]
#   /slave/photons/x     uint16   [6967274]
#   /slave/photons/y     uint16   [6967274]
# ...

# %%
countrateMaster = data.data.master.status.daq_counts[:]
countrateSlave = data.data.slave.status.daq_counts[:]

# %%
plt.figure()
plt.plot(np.diff(countrateMaster[::1000]))
plt.plot(np.diff(countrateSlave[::1000]))
plt.show()

# %%
data = Vault("d:/rawData/07_2Ions_12uW598.photons")

# %%
data
# Out:
# [d:/rawData/07_2Ions_12uW598.photons]
# Datasets:
#   /master/aux/aat      uint64   [298208]
#   /master/aux/aux      uint16   [298208]
#   /master/photons/a    uint16   [1079060]
#   /master/photons/aat  uint64   [1079060]
#   /master/photons/aux  uint16   [1079060]
#   /master/photons/tac  uint16   [1079060]
#   /master/photons/x    uint16   [1079060]
#   /master/photons/y    uint16   [1079060]
#   /master/status/aat   uint64   [901044]
#   /master/status/aux   uint16   [901044]
#   /master/status/daq_counts uint64   [901044]
#   /master/status/mcp_counts uint64   [901044]
#   /master/status/temperature float32  [901044]
#   /slave/aux/aat       uint64   [298216]
#   /slave/aux/aux       uint16   [298216]
#   /slave/photons/a     uint16   [1400993]
#   /slave/photons/aat   uint64   [1400993]
#   /slave/photons/aux   uint16   [1400993]
#   /slave/photons/tac   uint16   [1400993]
#   /slave/photons/x     uint16   [1400993]
#   /slave/photons/y     uint16   [1400993]
# ...

# %%
countrateMaster = data.data.master.status.daq_counts[:]
countrateSlave = data.data.slave.status.daq_counts[:]

# %%
plt.figure()
plt.plot(np.diff(countrateMaster[::1000]))
plt.plot(np.diff(countrateSlave[::1000]))
plt.show()

# %%
data = Vault("d:/rawData/07_2Ions_12uW578.photons")

# %%
data
# Out:
# [d:/rawData/07_2Ions_12uW578.photons]
# Datasets:
#   /master/aux/aat      uint64   [245664]
#   /master/aux/aux      uint16   [245664]
#   /master/photons/a    uint16   [5236000]
#   /master/photons/aat  uint64   [5236000]
#   /master/photons/aux  uint16   [5236000]
#   /master/photons/tac  uint16   [5236000]
#   /master/photons/x    uint16   [5236000]
#   /master/photons/y    uint16   [5236000]
#   /master/status/aat   uint64   [901208]
#   /master/status/aux   uint16   [901208]
#   /master/status/daq_counts uint64   [901208]
#   /master/status/mcp_counts uint64   [901208]
#   /master/status/temperature float32  [901208]
#   /slave/aux/aat       uint64   [245664]
#   /slave/aux/aux       uint16   [245664]
#   /slave/photons/a     uint16   [6938642]
#   /slave/photons/aat   uint64   [6938642]
#   /slave/photons/aux   uint16   [6938642]
#   /slave/photons/tac   uint16   [6938642]
#   /slave/photons/x     uint16   [6938642]
#   /slave/photons/y     uint16   [6938642]
# ...

# %%
countrateMaster = data.data.master.status.daq_counts[:]
countrateSlave = data.data.slave.status.daq_counts[:]

# %%
plt.figure()
plt.plot(np.diff(countrateMaster[::1000]))
plt.plot(np.diff(countrateSlave[::1000]))
plt.show()

# %%
data = Vault("d:/rawData/07_2Ions_12uW544.photons")

# %%
data
# Out:
# [d:/rawData/07_2Ions_12uW544.photons]
# Datasets:
#   /master/aux/aat      uint64   [227320]
#   /master/aux/aux      uint16   [227320]
#   /master/photons/a    uint16   [5774254]
#   /master/photons/aat  uint64   [5774254]
#   /master/photons/aux  uint16   [5774254]
#   /master/photons/tac  uint16   [5774254]
#   /master/photons/x    uint16   [5774254]
#   /master/photons/y    uint16   [5774254]
#   /master/status/aat   uint64   [901204]
#   /master/status/aux   uint16   [901204]
#   /master/status/daq_counts uint64   [901204]
#   /master/status/mcp_counts uint64   [901204]
#   /master/status/temperature float32  [901204]
#   /slave/aux/aat       uint64   [227320]
#   /slave/aux/aux       uint16   [227320]
#   /slave/photons/a     uint16   [7652148]
#   /slave/photons/aat   uint64   [7652148]
#   /slave/photons/aux   uint16   [7652148]
#   /slave/photons/tac   uint16   [7652148]
#   /slave/photons/x     uint16   [7652148]
#   /slave/photons/y     uint16   [7652148]
# ...

# %%
data = Vault("d:/rawData/07_2Ions_12uW544.photons")

# %%
data
# Out:
# [d:/rawData/07_2Ions_12uW544.photons]
# Datasets:
#   /master/aux/aat      uint64   [227320]
#   /master/aux/aux      uint16   [227320]
#   /master/photons/a    uint16   [5774254]
#   /master/photons/aat  uint64   [5774254]
#   /master/photons/aux  uint16   [5774254]
#   /master/photons/tac  uint16   [5774254]
#   /master/photons/x    uint16   [5774254]
#   /master/photons/y    uint16   [5774254]
#   /master/status/aat   uint64   [901204]
#   /master/status/aux   uint16   [901204]
#   /master/status/daq_counts uint64   [901204]
#   /master/status/mcp_counts uint64   [901204]
#   /master/status/temperature float32  [901204]
#   /slave/aux/aat       uint64   [227320]
#   /slave/aux/aux       uint16   [227320]
#   /slave/photons/a     uint16   [7652148]
#   /slave/photons/aat   uint64   [7652148]
#   /slave/photons/aux   uint16   [7652148]
#   /slave/photons/tac   uint16   [7652148]
#   /slave/photons/x     uint16   [7652148]
#   /slave/photons/y     uint16   [7652148]
# ...

# %%
countrateMaster = data.data.master.status.daq_counts[:]
countrateSlave = data.data.slave.status.daq_counts[:]

# %%
plt.figure()
plt.plot(np.diff(countrateMaster[::1000]))
plt.plot(np.diff(countrateSlave[::1000]))
plt.show()

# %%
data = Vault("d:/rawData/07_2Ions_12uW686.photons")

# %%
data
# Out:
# [d:/rawData/07_2Ions_12uW686.photons]
# Datasets:
#   /master/aux/aat      uint64   [239040]
#   /master/aux/aux      uint16   [239040]
#   /master/photons/a    uint16   [5267072]
#   /master/photons/aat  uint64   [5267072]
#   /master/photons/aux  uint16   [5267072]
#   /master/photons/tac  uint16   [5267072]
#   /master/photons/x    uint16   [5267072]
#   /master/photons/y    uint16   [5267072]
#   /master/status/aat   uint64   [901200]
#   /master/status/aux   uint16   [901200]
#   /master/status/daq_counts uint64   [901200]
#   /master/status/mcp_counts uint64   [901200]
#   /master/status/temperature float32  [901200]
#   /slave/aux/aat       uint64   [239040]
#   /slave/aux/aux       uint16   [239040]
#   /slave/photons/a     uint16   [6982089]
#   /slave/photons/aat   uint64   [6982089]
#   /slave/photons/aux   uint16   [6982089]
#   /slave/photons/tac   uint16   [6982089]
#   /slave/photons/x     uint16   [6982089]
#   /slave/photons/y     uint16   [6982089]
# ...

# %%
countrateMaster = data.data.master.status.daq_counts[:]
countrateSlave = data.data.slave.status.daq_counts[:]

# %%
plt.figure()
plt.plot(np.diff(countrateMaster[::1000]))
plt.plot(np.diff(countrateSlave[::1000]))
plt.show()

# %%
data = Vault("d:/rawData/07_2Ions_12uW610.photons")

# %%
data
# Out:
# [d:/rawData/07_2Ions_12uW610.photons]
# Datasets:
#   /master/aux/aat      uint64   [228160]
#   /master/aux/aux      uint16   [228160]
#   /master/photons/a    uint16   [5277176]
#   /master/photons/aat  uint64   [5277176]
#   /master/photons/aux  uint16   [5277176]
#   /master/photons/tac  uint16   [5277176]
#   /master/photons/x    uint16   [5277176]
#   /master/photons/y    uint16   [5277176]
#   /master/status/aat   uint64   [901208]
#   /master/status/aux   uint16   [901208]
#   /master/status/daq_counts uint64   [901208]
#   /master/status/mcp_counts uint64   [901208]
#   /master/status/temperature float32  [901208]
#   /slave/aux/aat       uint64   [228164]
#   /slave/aux/aux       uint16   [228164]
#   /slave/photons/a     uint16   [6977215]
#   /slave/photons/aat   uint64   [6977215]
#   /slave/photons/aux   uint16   [6977215]
#   /slave/photons/tac   uint16   [6977215]
#   /slave/photons/x     uint16   [6977215]
#   /slave/photons/y     uint16   [6977215]
# ...

# %%
countrateMaster = data.data.master.status.daq_counts[:]
countrateSlave = data.data.slave.status.daq_counts[:]

# %%
plt.figure()
plt.plot(np.diff(countrateMaster[::1000]))
plt.plot(np.diff(countrateSlave[::1000]))
plt.show()

# %%
data = Vault("d:/rawData/07_2Ions_12uW686.photons")

# %%
data
# Out:
# [d:/rawData/07_2Ions_12uW686.photons]
# Datasets:
#   /master/aux/aat      uint64   [239040]
#   /master/aux/aux      uint16   [239040]
#   /master/photons/a    uint16   [5267072]
#   /master/photons/aat  uint64   [5267072]
#   /master/photons/aux  uint16   [5267072]
#   /master/photons/tac  uint16   [5267072]
#   /master/photons/x    uint16   [5267072]
#   /master/photons/y    uint16   [5267072]
#   /master/status/aat   uint64   [901200]
#   /master/status/aux   uint16   [901200]
#   /master/status/daq_counts uint64   [901200]
#   /master/status/mcp_counts uint64   [901200]
#   /master/status/temperature float32  [901200]
#   /slave/aux/aat       uint64   [239040]
#   /slave/aux/aux       uint16   [239040]
#   /slave/photons/a     uint16   [6982089]
#   /slave/photons/aat   uint64   [6982089]
#   /slave/photons/aux   uint16   [6982089]
#   /slave/photons/tac   uint16   [6982089]
#   /slave/photons/x     uint16   [6982089]
#   /slave/photons/y     uint16   [6982089]
# ...

# %%
countrateMaster = data.data.master.status.daq_counts[:]
countrateSlave = data.data.slave.status.daq_counts[:]

# %%
plt.figure()
plt.plot(np.diff(countrateMaster[::1000]))
plt.plot(np.diff(countrateSlave[::1000]))
plt.show()

# %%
data = Vault("d:/rawData/07_2Ions_12uW595.photons")

# %%
data
# Out:
# [d:/rawData/07_2Ions_12uW595.photons]
# Datasets:
#   /master/aux/aat      uint64   [242436]
#   /master/aux/aux      uint16   [242436]
#   /master/photons/a    uint16   [5059872]
#   /master/photons/aat  uint64   [5059872]
#   /master/photons/aux  uint16   [5059872]
#   /master/photons/tac  uint16   [5059872]
#   /master/photons/x    uint16   [5059872]
#   /master/photons/y    uint16   [5059872]
#   /master/status/aat   uint64   [901183]
#   /master/status/aux   uint16   [901183]
#   /master/status/daq_counts uint64   [901183]
#   /master/status/mcp_counts uint64   [901183]
#   /master/status/temperature float32  [901183]
#   /slave/aux/aat       uint64   [242440]
#   /slave/aux/aux       uint16   [242440]
#   /slave/photons/a     uint16   [6705018]
#   /slave/photons/aat   uint64   [6705018]
#   /slave/photons/aux   uint16   [6705018]
#   /slave/photons/tac   uint16   [6705018]
#   /slave/photons/x     uint16   [6705018]
#   /slave/photons/y     uint16   [6705018]
# ...

# %%
countrateMaster = data.data.master.status.daq_counts[:]
countrateSlave = data.data.slave.status.daq_counts[:]

# %%
plt.figure()
plt.plot(np.diff(countrateMaster[::1000]))
plt.plot(np.diff(countrateSlave[::1000]))
plt.show()

# %%
data = Vault("d:/rawData/08_2Ions_12uW54.photons")

# %%
data
# Out:
# [d:/rawData/08_2Ions_12uW54.photons]
# Datasets:
#   /master/aux/aat      uint64   [243764]
#   /master/aux/aux      uint16   [243764]
#   /master/photons/a    uint16   [4279565]
#   /master/photons/aat  uint64   [4279565]
#   /master/photons/aux  uint16   [4279565]
#   /master/photons/tac  uint16   [4279565]
#   /master/photons/x    uint16   [4279565]
#   /master/photons/y    uint16   [4279565]
#   /master/status/aat   uint64   [901222]
#   /master/status/aux   uint16   [901222]
#   /master/status/daq_counts uint64   [901222]
#   /master/status/mcp_counts uint64   [901222]
#   /master/status/temperature float32  [901222]
#   /slave/aux/aat       uint64   [243768]
#   /slave/aux/aux       uint16   [243768]
#   /slave/photons/a     uint16   [5648083]
#   /slave/photons/aat   uint64   [5648083]
#   /slave/photons/aux   uint16   [5648083]
#   /slave/photons/tac   uint16   [5648083]
#   /slave/photons/x     uint16   [5648083]
#   /slave/photons/y     uint16   [5648083]
# ...

# %%
countrateMaster = data.data.master.status.daq_counts[:]
countrateSlave = data.data.slave.status.daq_counts[:]

# %%
plt.figure()
plt.plot(np.diff(countrateMaster[::1000]))
plt.plot(np.diff(countrateSlave[::1000]))
plt.show()

# %%
data = Vault("d:/rawData/08_2Ions_12uW56.photons")

# %%
data
# Out:
# [d:/rawData/08_2Ions_12uW56.photons]
# Datasets:
#   /master/aux/aat      uint64   [245436]
#   /master/aux/aux      uint16   [245436]
#   /master/photons/a    uint16   [4054781]
#   /master/photons/aat  uint64   [4054781]
#   /master/photons/aux  uint16   [4054781]
#   /master/photons/tac  uint16   [4054781]
#   /master/photons/x    uint16   [4054781]
#   /master/photons/y    uint16   [4054781]
#   /master/status/aat   uint64   [901204]
#   /master/status/aux   uint16   [901204]
#   /master/status/daq_counts uint64   [901204]
#   /master/status/mcp_counts uint64   [901204]
#   /master/status/temperature float32  [901204]
#   /slave/aux/aat       uint64   [245440]
#   /slave/aux/aux       uint16   [245440]
#   /slave/photons/a     uint16   [5356340]
#   /slave/photons/aat   uint64   [5356340]
#   /slave/photons/aux   uint16   [5356340]
#   /slave/photons/tac   uint16   [5356340]
#   /slave/photons/x     uint16   [5356340]
#   /slave/photons/y     uint16   [5356340]
# ...

# %%
countrateMaster = data.data.master.status.daq_counts[:]
countrateSlave = data.data.slave.status.daq_counts[:]

# %%
plt.figure()
plt.plot(np.diff(countrateMaster[::1000]))
plt.plot(np.diff(countrateSlave[::1000]))
plt.show()
